# %%
import pandas as pd

def strain_metadata_extractor(description):
    query = description.split()
    
    ctr = 0
    for q in query:
        if q.startswith("Annotated"):
            break
        else:
            ctr = ctr+1

    genus = query[0]
    species = query[1]

    if ctr == 4:
        strain = " ".join(query[2:4])
    elif ctr == 3:
        strain = query[2]

    return genus, species, strain

# %%
df = pd.read_csv("../tables/clean_metadata.csv", index_col=0)
df.head(1)
# Out:
#                                                 name resource_id  \
# 0  Aspergillus acristatulus CBS 119.55 Annotated ...    Aspacri1
#
#                            resource_link  project_id  \
# 0  https://mycocosm.jgi.doe.gov/Aspacri1     1052020
#
#                                         project_link          folder_name  \
# 0  https://genome.jgi.doe.gov/portal/pages/projec...  AspacrStandDraft_FD
#
#                                     related_projects    status release_date  \
# 0  ['SP 1052022', 'SP 1052021', 'AP 1052024', 'AP...  Complete   2014-03-25
#
#      contact_name          contact_mail  \
# 0  Scott E. Baker  scott.baker@pnnl.gov
#
#                                    masked_assemblies assembly_id_alias  \
# 0  /datadrive/matin_other_projects/jgi_aspergillu...          Aspacri1
#
#   annotation_id_alias                                        annotations
# 0            Aspacri1  /datadrive/matin_other_projects/jgi_aspergillu...

# %%
genus_all = []
species_all = []
strain_all = []

for i in df.name:
    genus, species, strain = strain_metadata_extractor(i)
    genus_all.append(genus)
    species_all.append(species)
    strain_all.append(strain)

# %%
# generate sample file
df_sample = pd.DataFrame()
df_sample.loc[:, "genome_id"] = df.loc[:, "project_id"]
df_sample.loc[:, "source"] = 'custom'
df_sample.loc[:, "genus"] = genus_all
df_sample.loc[:, "species"] = species_all
df_sample.loc[:, "strain"] = strain_all
df_sample.loc[:, "description"] = df.loc[:, "name"]
df_sample.reset_index(drop=True)
df_sample.to_csv("../config/samples.csv", index=False)

# %%
# generate unit file
df_units = pd.DataFrame()
df_units.loc[:, "genome_id"] = df.loc[:, "project_id"]
df_units.loc[:, "unit"] = 1
df_units.loc[:, "assembly"] = [i.replace("/datadrive/matin_other_projects/jgi_aspergillus/", "") for i in df.loc[:, "masked_assemblies"]]
df_units.loc[:, "annotations"] = [i.replace("/datadrive/matin_other_projects/jgi_aspergillus/", "") for i in df.loc[:, "annotations"]]
df_units.reset_index(drop=True)
df_units.to_csv("../config/units.csv", index=False)

# %%
" ".join(df.name[0].split()[2:4])
# Out:
# 'CBS 119.55'

# %%
genus_all = []
species_all = []
strain_all = []

for i in df.name:
    genus, species, strain = strain_metadata_extractor(i)
    genus_all.append(genus)
    species_all.append(species)
    strain_all.append(species)
# Out:
# ('Aspergillus', 'acristatulus', 'CBS 119.55')
# ('Aspergillus', 'affinis', 'CBS 129190')
# ('Aspergillus', 'alabamensis', 'IBT 12702')
# ('Aspergillus', 'albertensis', 'IBT 14317')
# ('Aspergillus', 'allahabadii', 'CBS 164.63')
# ('Aspergillus', 'alliaceus', 'CBS 536.65')
# ('Aspergillus', 'ambiguus', 'CBS 117.58')
# ('Aspergillus', 'amoenus', 'CBS 111.32')
# ('Aspergillus', 'amylovorus', 'CBS 600.67')
# ('Aspergillus', 'angustatus', 'CBS 273.65')
# ('Aspergillus', 'appendiculatus', 'CBS 374.75')
# ('Aspergillus', 'arachidicola', 'CBS 117612')
# ('Aspergillus', 'arxii', 'CBS 525.83')
# ('Aspergillus', 'assulatus', 'IBT 27911')
# ('Aspergillus', 'astellatus', 'CBS 261.93')
# ('Aspergillus', 'aurantiobrunneus', 'CBS 465.65')
# ('Aspergillus', 'aurantiopurpureus', 'CBS 140608')
# ('Aspergillus', 'aureolatus', 'CBS 190.65')
# ('Aspergillus', 'aureoluteus', 'CBS 105.55')
# ('Aspergillus', 'aureoterreus', 'CBS 503.65')
# ('Aspergillus', 'austroafricanus', 'IBT 32289')
# ('Aspergillus', 'avenaceus', 'IBT 18842')
# ('Aspergillus', 'bertholletius', 'IBT 29228')
# ('Aspergillus', 'biplanus', 'CBS 468.65')
# ('Aspergillus', 'bisporus', 'CBS 707.71')
# ('Aspergillus', 'botucatensis', 'CBS 114221')
# ('Aspergillus', 'brevijanus', 'CBS 111.46')
# ('Aspergillus', 'brevipes', 'CBS 118.53')
# ('Aspergillus', 'brevistipitatus', 'CBS 135454')
# ('Aspergillus', 'caelatus', 'CBS 763.97')
# ('Aspergillus', 'caespitosus', 'CBS 103.45')
# ('Aspergillus', 'calidoustus', 'CBS 113228')
# ('Aspergillus', 'californicus', 'CBS 123895')
# ('Aspergillus', 'caninus', 'CBS 128032')
# ('Aspergillus', 'capensis', 'CBS 138188')
# ('Aspergillus', 'capperatus', 'DTO 337-E6')
# ('Aspergillus', 'carlsbadensis', 'CBS 123894')
# ('Aspergillus', 'cejpii', 'CBS 157.66')
# ('Aspergillus', 'cervinus', 'CBS 196.64')
# ('Aspergillus', 'chevalieri', 'CBS 522.65')
# ('Aspergillus', 'christenseniae', 'CBS 411.64')
# ('Aspergillus', 'chrysellus', 'CBS 472.65')
# ('Aspergillus', 'cibarius', 'DTO 197-D3')
# ('Aspergillus', 'clavatonanicus', 'CBS 474.65')
# ('Aspergillus', 'cleistominutus', 'CBS 200.75')
# ('Aspergillus', 'conjunctus', 'CBS 476.65')
# ('Aspergillus', 'coreanus', 'CBS 117059')
# ('Aspergillus', 'coremiiformis', 'CBS 553.77')
# ('Aspergillus', 'corrugatus', 'CBS 191.77')
# ('Aspergillus', 'costiformis', 'CBS 101749')
# ('Aspergillus', 'creber', 'IBT 32277')
# ('Aspergillus', 'cretensis', 'CBS 112802')
# ('Aspergillus', 'crustosus', 'CBS 478.65')
# ('Aspergillus', 'cumulatus', 'DTO 311-F5')
# ('Aspergillus', 'deflectus', 'CBS 109.55')
# ('Aspergillus', 'dentatus', 'CBS 114.63')
# ('Aspergillus', 'desertorum', 'CBS 653.73')
# ('Aspergillus', 'dimorphicus', 'CBS 649.79')
# ('Aspergillus', 'dromiae', 'CBS 140633')
# ('Aspergillus', 'duricaulis', 'CBS 481.65')
# ('Aspergillus', 'egyptiacus', 'CBS 656.73')
# ('Aspergillus', 'elegans', 'CBS 116.39')
# ('Aspergillus', 'endophyticus', 'DTO 354-I2')
# ('Aspergillus', 'falconensis', 'CBS 271.91')
# ('Aspergillus', 'ferenczii', 'CBS 121594')
# ('Aspergillus', 'filifera', 'CBS 114510')
# ('Aspergillus', 'flavipes', 'IBT 22552')
# ('Aspergillus', 'floccosus', 'CBS 116.37')
# ('Aspergillus', 'flocculosus', 'CBS 112785')
# ('Aspergillus', 'floridensis', 'DTO 198-A8')
# ('Aspergillus', 'foveolata', 'CBS 279.81')
# ('Aspergillus', 'frequens', 'CBS 586.65')
# ('Aspergillus', 'fructiculosa', 'CBS 989.72')
# ('Aspergillus', 'fumigatiaffinis', 'CBS 117186')
# ('Aspergillus', 'fumisynnematus', 'IBT 28474')
# ('Aspergillus', 'funiculosus', 'CBS 116.56')
# ('Aspergillus', 'galapagensis', 'CBS 117522')
# ('Aspergillus', 'germanicus', 'CBS 123887')
# ('Aspergillus', 'giganteus', 'CBS 515.65')
# ('Aspergillus', 'granulosus', 'CBS 588.65')
# ('Aspergillus', 'haitiensis', 'CBS 468.91')
# ('Aspergillus', 'hiratsukae', 'CBS 294.93')
# ('Aspergillus', 'hortai', 'IBT 26384')
# ('Aspergillus', 'igneus', 'CBS 466.65')
# ('Aspergillus', 'iizukae', 'CBS 541.69')
# ('Aspergillus', 'indicus', 'CBS 952.97')
# ('Aspergillus', 'insolitus', 'CBS 384.61')
# ('Aspergillus', 'insuetus', 'CBS 107.25')
# ('Aspergillus', 'karnatakaensis', 'CBS 102800')
# ('Aspergillus', 'keveii', 'CBS 209.92')
# ('Aspergillus', 'laciniosus', 'CBS 117721')
# ('Aspergillus', 'lentulus', 'CBS 117885')
# ('Aspergillus', 'leporis', 'CBS 151.66')
# ('Aspergillus', 'longivesica', 'CBS 530.71')
# ('Aspergillus', 'lucknowensis', 'CBS 449.75')
# ('Aspergillus', 'luppii', 'CBS 653.74')
# ('Aspergillus', 'mangaliensis', 'DTO 316-C1')
# ('Aspergillus', 'megasporus', 'DTO 048-I3')
# ('Aspergillus', 'microcysticus', 'CBS 120.58')
# ('Aspergillus', 'minisclerotigenes', 'CBS 117635')
# ('Aspergillus', 'miraensis', 'CBS 140625')
# ('Aspergillus', 'mottae', 'CBS 130016')
# ('Aspergillus', 'multicolor', 'CBS 133.54')
# ('Aspergillus', 'multiplicatus', 'CBS 646958')
# ('Aspergillus', 'muricatus', 'CBS 112808')
# ('Aspergillus', 'nakazawae', 'CBS 640.78')
# ('Aspergillus', 'navahoensis', 'CBS 351.81')
# ('Aspergillus', 'neoauricomus', 'CBS 112787')
# ('Aspergillus', 'neocaesiellus', 'DTO 356-D2')
# ('Aspergillus', 'neoconicus', 'CBS 233.90')
# ('Aspergillus', 'neoechinulatus', 'CBS 120.55')
# ('Aspergillus', 'neoflavipes', 'CBS 260.73')
# ('Aspergillus', 'neoindicus', 'CBS 444.75')
# ('Aspergillus', 'neostromatioides', 'CBS 265.73')
# ('Aspergillus', 'neowarcupii', 'IBT 29024')
# ('Aspergillus', 'nishimurae', 'IFM 54133')
# ('Aspergillus', 'niveus', 'CBS 471.91')
# ('Aspergillus', 'nomius', 'IBT 12657')
# ('Aspergillus', 'novoparasiticus', 'CBS 126849')
# ('Aspergillus', 'nutans', 'CBS 121.56')
# ('Aspergillus', 'oerlinghausenensis', 'CBS 139183')
# ('Aspergillus', 'olivicola', 'CBS 597.65')
# ('Aspergillus', 'ostianus', 'CBS 103.07')
# ('Aspergillus', 'pachycristatus', 'IBT 23550')
# ('Aspergillus', 'papuensis', 'CBS 841.96')
# ('Aspergillus', 'parafelis', 'IBT 34187')
# ('Aspergillus', 'parasiticus', 'CBS 117618')
# ('Aspergillus', 'parvisclerotigenus', 'CBS 121.62')
# ('Aspergillus', 'parvulus', 'CBS 136.61')
# ('Aspergillus', 'penicilloides', 'CBS 540.65')
# ('Aspergillus', 'pernambucoensis', 'CBS 137449')
# ('Aspergillus', 'persii', 'CBS 112795')
# ('Aspergillus', 'phaeropenciillioides', 'DTO 356-D6')
# ('Aspergillus', 'primulinus', 'CBS 253.94')
# ('Aspergillus', 'pseudocaelatus', 'CBS 117616')
# ('Aspergillus', 'pseudodeflectus', 'CBS 756.74')
# ('Aspergillus', 'pseudofelis', 'IBT 34107')
# ('Aspergillus', 'pseudotamarii', 'CBS 117625')
# ('Aspergillus', 'pseudoterreus', 'DTO 47-E6')
# ('Aspergillus', 'pseudoustus', 'CBS 123904')
# ('Aspergillus', 'pseudoviridinutans', 'IBT 34175')
# ('Aspergillus', 'pulvericola', 'CBS 137327')
# ('Aspergillus', 'puulaauensis', 'IBT 32284')
# ('Aspergillus', 'quadrilineatus', 'CBS 853.96')
# ('Aspergillus', 'quadrilineatus', 'CBS 937.73')
# ('Aspergillus', 'rambellii', 'CBS 100887')
# ('Aspergillus', 'recurvatus', 'CBS 496.65')
# ('Aspergillus', 'restrictus', 'CBS 118.33')
# ('Aspergillus', 'rhizopodus', 'CBS 450.75')
# ('Aspergillus', 'robustus', 'CBS 428.77')
# ('Aspergillus', 'roseoglobulosus', 'CBS 112800')
# ('Aspergillus', 'sclerotiorum', 'CBS 549.65')
# ('Aspergillus', 'sepultus', 'CBS 257.85')
# ('Aspergillus', 'sergii', 'CBS 130017')
# ('Aspergillus', 'sesamicola', 'CBS 137324')
# ('Aspergillus', 'shendaweii', 'IBT 34197')
# ('Aspergillus', 'siamensis', 'CBS 137452')
# ('Aspergillus', 'silvaticus', 'CBS 128.55')
# ('Aspergillus', 'similis', 'CBS 293.93')
# ('Aspergillus', 'spathulatus', 'CBS 408.89')
# ('Aspergillus', 'spectabilis', 'CBS 429.77A')
# ('Aspergillus', 'spinosus', 'CBS 483.65')
# ('Aspergillus', 'spiritus', 'DTO 241-G7')
# ('Aspergillus', 'stella-maris', 'CBS 113639')
# ('Aspergillus', 'stellifer', 'CBS 598.65')
# ('Aspergillus', 'stercoraria', 'CBS 428.93')
# ('Aspergillus', 'subauricomus', 'CBS 638.78')
# ('Aspergillus', 'sublatus', 'IBT 19356')
# ('Aspergillus', 'subramanianii', 'CBS 138230')
# ('Aspergillus', 'subversicolor', 'IBT 32280')
# ('Aspergillus', 'sulphureoviridis', 'CBS 140626')
# ('Aspergillus', 'taichungensis', 'IBT 19404')
# ('Aspergillus', 'tamarii', 'CBS 117626')
# ('Aspergillus', 'tanneri', 'DTO 303-I8')
# ('Aspergillus', 'templicola', 'CBS 138181')
# ('Aspergillus', 'tennesseensis', 'IBT 32283')
# ('Aspergillus', 'tetrazonus', 'CBS 591.65A')
# ('Aspergillus', 'thermomutatus', 'CBS 207.92')
# ('Aspergillus', 'thesauricus', 'IBT 34227')
# ('Aspergillus', 'transcarpathicus', 'CBS 423.68')
# ('Aspergillus', 'transmontanensis', 'CBS 130015')
# ('Aspergillus', 'triticus', 'CBS 266.81')
# ('Aspergillus', 'tsurutae', 'IBT 34206')
# ('Aspergillus', 'turcosus', 'IBT 27921')
# ('Aspergillus', 'udagawae', 'CBS 114217')
# ('Aspergillus', 'umbrosus', 'CBS 117.46')
# ('Aspergillus', 'undulatus', 'CBS 261.88')
# ('Aspergillus', 'varians', 'CBS 505.65')
# ('Aspergillus', 'viridinutans', 'CBS 127.56')
# ('Aspergillus', 'waksmanii', 'IBT 31900')
# ('Aspergillus', 'welwitchiae', 'CBS 139.54b')
# ('Aspergillus', 'westerdijkiae', 'CBS 112803')
# ('Aspergillus', 'westlandensis', 'CBS 123905')
# ('Aspergillus', 'xerophilus', 'CBS 938.73')
# ('Penicillium', 'antarcticum', 'DTO 356-E5')
# ('Penicillium', 'malodoratum', 'CBS 490.65')
# ('Penicillium', 'solitum', 'IBT 30036')
# ('Penicillium', 'sp.', 'DTU1')
